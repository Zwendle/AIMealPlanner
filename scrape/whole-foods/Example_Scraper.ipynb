# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import time

BASE = "https://www.wholefoodsmarket.com/api/products/category/produce"
STORE_ID = "10031"
LIMIT = 60

session = requests.Session()
session.headers.update({
    "User-Agent": "Mozilla/5.0",
    "Accept": "application/json, text/plain, */*",
    "Referer": "https://www.wholefoodsmarket.com/products/produce",
    "Accept-Language": "en-US,en;q=0.9",
})

all_products = []
offset = 0

while True:
    params = {
        "leafCategory": "produce",
        "store": STORE_ID,
        "limit": str(LIMIT),
        "offset": str(offset),
    }
    r = session.get(BASE, params=params, timeout=30)
    r.raise_for_status()
    data = r.json()

    # adjust these keys to match the actual JSON you see in DevTools
    page_items = (
        data.get("results")
        or data.get("items")
        or data.get("products")
        or []
    )

    if not page_items:
        break

    all_products.extend(page_items)

    # Stop conditions: shorter page or explicit flag
    if len(page_items) < LIMIT or data.get("hasMore") is False:
        break

    offset += LIMIT
    time.sleep(0.8)  # be polite

# print(f"Total products: {len(all_products)}")
# # Inspect one item to map out fields
# if all_products:
#     print(all_products[0])
all_products
# Out:
# [{'regularPrice': 3.99,
#   'name': 'Organic Cherry Tomatoes',
#   'slug': 'produce-organic-cherry-tomatoes-b07shc2qfp',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/579933d5c618f53639e8d51c_produce-redcherrytomatoes-pt-1.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 3.49,
#   'name': 'Organic English Cucumbers',
#   'slug': 'produce-organic-english-cucumbers-b07dlgkrtd',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/56fb451a6bd9d81100a26821_long-english-cucumber.2-1-.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 4.99,
#   'name': 'Veg-land Organic Mini Sweet Peppers (16 Oz)',
#   'slug': 'vegland-inc-vegland-organic-mini-sweet-peppers-16-oz-b07811t3y5',
#   'brand': 'Veg-Land Inc.',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/5e013cc43761e572643cfe4b_dld-upc-00762453284061-glamor-frontpackageglamor-2019-10-16t16-25-21-30c5a4aa-7a3e-4a3e-86fd-aa4934860f1d-1577139395547.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'name': 'Organic Dino Kale Greens',
#   'slug': 'grimmway-farms-organic-dino-kale-greens-b07nfj8z5j',
#   'brand': 'Grimmway Farms',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/601c092c97e3c63f5a86092f_00078783906000-glamor-frontpackageglamor-2021-01-14t13-40-24-iphone-7-quality-90-1-21-8-user-5c4f16e4fc9c91accd101ce4-0lwg-514262.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 3.19,
#   'name': 'Packaged Vegetables, Green Beans - Trimmed',
#   'slug': '365-by-whole-foods-market-packaged-vegetables-green-beans-trimmed-b078j118fh',
#   'brand': '365 by Whole Foods Market',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/5f95b004ee200ab2da74f160_099482466657-front.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 5.99,
#   'name': 'Organic Fuji Apples 3lb Bag',
#   'slug': 'produce-organic-fuji-apples-3lb-bag-b07fxx2y32',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/57b5e4fd9580719c37f59ab8_snochief-fujiapples-2.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.99,
#   'name': 'Organic Slicing Cucumbers',
#   'slug': 'produce-organic-slicing-cucumbers-b0040qylw8',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/56fb451a6bd9d81100a26821_long-english-cucumber.2-1-.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 5.99,
#   'name': 'Organic Granny Smith Apples Bag',
#   'slug': 'produce-organic-granny-smith-apples-bag-mm8a1lo9',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/56e608449cdbb7110015214e_365_-granny-smith-apple.1.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 3.49,
#   'name': 'Organic Grape Tomatoes',
#   'slug': 'produce-organic-grape-tomatoes-b07g4hqhbq',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/57c980ec48e5662aa9061d43_produce-cherrytomatoes-red-1.JPG',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 4.99,
#   'name': 'Blueberries',
#   'slug': 'produce-blueberries-2bf3fa99',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/5dc032532a18cfd6dac30f59_blueberries.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 3.99,
#   'name': 'Organic Baby Spinach Salad',
#   'slug': 'whole-foods-market-organic-baby-spinach-salad-b088k6v6bn',
#   'brand': 'Whole Foods Market',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/62d09944d707891144dac32e_0099482466732-glamor-front-2022-03-14t18-27-59-iphone-x-quality-90-1-29-0-user-5984ad42a967f880524de2c4-od8y-427265.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 4.99,
#   'name': 'Brussels Organic Sprouts, 16 Ounce',
#   'slug': 'produce-brussels-organic-sprouts-16-ounce-b004daqpr0',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/653c1d944a463c556feffd0d_2023-10-27_20-29-20_front.main.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 3.39,
#   'name': 'Organic Spring Mix',
#   'slug': 'whole-foods-market-organic-spring-mix-b07php7cky',
#   'brand': 'Whole Foods Market',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/6683731c59289e04dd330ebe_2024-07-08_15-11-54_front.main.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'name': 'Organic White Onion',
#   'slug': 'produce-organic-white-onion-b000rgznfy',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31p5knBTAYL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 1.99,
#   'name': 'Zucchini Squash',
#   'slug': 'produce-zucchini-squash-b000p6g1ac',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31XATyU-YeL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 2.99,
#   'name': 'Organic Red Onion',
#   'slug': 'produce-organic-red-onion-b000p6j1fe',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/311kdW8Y3OL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 2.49,
#   'name': 'Vine On Tomato',
#   'slug': 'produce-vine-on-tomato-b001l1krsc',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41pFcaQ1i7L.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 6.99,
#   'name': 'Organic Garlic',
#   'slug': 'produce-organic-garlic-b0035aprlo',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/319evtDcboL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 5.99,
#   'name': 'Organic Yellow Onion Bag',
#   'slug': 'produce-organic-yellow-onion-bag-b07ftjcyl3',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51P4tZjSTbL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.99,
#   'name': 'White Onion',
#   'slug': 'produce-white-onion-b084kcv6zf',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31p5knBTAYL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 1.99,
#   'name': 'Organic Cilantro',
#   'slug': 'produce-organic-cilantro-b000p6g0ik',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41PPcCmhqaL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.29,
#   'name': 'Eggplant',
#   'slug': 'produce-eggplant-b000p6g2n8',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/310IOCIK0rL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 5.99,
#   'name': 'Organic Baby Spinach, 16 OZ',
#   'slug': '365-by-whole-foods-market-organic-baby-spinach-16-oz-b074h55njk',
#   'brand': '365 by Whole Foods Market',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41tlB67dt1L.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.19,
#   'name': 'English Cucumbers',
#   'slug': 'produce-english-cucumbers-b001plet96',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31jFVSWrnTL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 5.99,
#   'name': 'Organic Spring Salad Mix, 16 OZ',
#   'slug': '365-by-whole-foods-market-organic-spring-salad-mix-16-oz-b074h57s5g',
#   'brand': '365 by Whole Foods Market',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41JIzmSUthL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.09,
#   'name': 'Slicing Cucumbers',
#   'slug': 'produce-slicing-cucumbers-b001w3t2e4',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31JoL1X4sML.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 5.99,
#   'name': 'Organic Blueberries Pint',
#   'slug': 'produce-organic-blueberries-pint-b003aykyig',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/412HQvbct5L.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.99,
#   'name': 'Roma Tomato',
#   'slug': 'produce-roma-tomato-b07fyybg8j',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31z9K0lZg6L.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 2.79,
#   'name': 'Slicer Tomato',
#   'slug': 'produce-slicer-tomato-b07fz73kr5',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41ANjbBi12L.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 5.99,
#   'name': 'Organic Hass Avocados',
#   'slug': 'produce-organic-hass-avocados-b07fycb4wx',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/414WfDBOE3L.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.19,
#   'name': 'Green Bell Pepper',
#   'slug': 'produce-green-bell-pepper-b001plesvu',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31AZ7E03qGL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 2.99,
#   'name': 'Organic Large Hass Avocados',
#   'slug': 'produce-organic-large-hass-avocados-b0b2w8hbz8',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51ukRMsmDIL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'name': 'Organic Basil',
#   'slug': 'produce-organic-basil-b07gxsrd22',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41w3cfnDTeL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.49,
#   'name': 'Organic Loose Carrots',
#   'slug': 'produce-organic-loose-carrots-b07fzj5322',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41jYs7opN-L.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 2.99,
#   'name': 'Celery Bunch',
#   'slug': 'produce-celery-bunch-b000nskb80',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31jxix5C1YL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.29,
#   'name': 'Russet Potato',
#   'slug': 'produce-russet-potato-b000nskb7q',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41zQV1q9L6L.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 6.99,
#   'name': 'Baby Green Leaf Lettuce, 8 OZ',
#   'slug': 'produce-baby-green-leaf-lettuce-8-oz-b0c7m4f2gw',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41E-MMFNr9L.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'name': 'Organic Baby Spinach Salad, 5 OZ',
#   'slug': '365-by-whole-foods-market-organic-baby-spinach-salad-5-oz-b074h4wrng',
#   'brand': '365 by Whole Foods Market',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41-id9-SVjL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 5.99,
#   'name': '365 by Whole Foods Market, Organic 50-50 Blend, Baby Spinach & Spring Mix, 16 Ounce',
#   'slug': '365-by-whole-foods-market-365-by-whole-foods-market-organic-5050-blend-baby-spinach-spring-mix-16-ounce-b074h64brp',
#   'brand': '365 by Whole Foods Market',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41OX3zgyUmL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.89,
#   'name': '365 Everyday Value Organic Garlic Ali (3 Bulbs), 3 ct (us)',
#   'slug': 'produce-365-everyday-value-organic-garlic-ali-3-bulbs-3-ct-us-b07nr3lf35',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31CskJVj-ML.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'name': 'Organic Green Kale',
#   'slug': 'produce-organic-green-kale-b000p6h2dm',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41r3YVnDroL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.99,
#   'name': 'Red Grapefruit',
#   'slug': 'produce-red-grapefruit-b000nsiaga',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41GhpIJAS8L.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 0.69,
#   'name': 'Bi-color Corn',
#   'slug': 'produce-bicolor-corn-b000p7bjmq',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31J4xr2xUDL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.99,
#   'name': 'Organic Green Cabbage',
#   'slug': 'produce-organic-green-cabbage-b000p6h29q',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31ZvxNZiq0L.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 0.59,
#   'name': 'Banana',
#   'slug': 'produce-banana-b07fyykkqk',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31dke4F-cTL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 1.69,
#   'name': 'Vidalia Onion',
#   'slug': 'produce-vidalia-onion-b07fzhmvx7',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41hc9E9GpYL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 1.69,
#   'name': 'Sweet Onion',
#   'slug': 'produce-sweet-onion-b003imltxe',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/410K5EttA6L.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 2.99,
#   'name': 'Organic Rosemary',
#   'slug': 'produce-organic-rosemary-b00luoze3s',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31DXG8k0vHL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.99,
#   'name': 'Organic Italian Parsley',
#   'slug': 'produce-organic-italian-parsley-b000rgwk50',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/414bgszFEIL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.99,
#   'name': 'Organic Curly Parsley Bunch',
#   'slug': 'produce-organic-curly-parsley-bunch-b07hfck9g7',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41RYw1rUEVL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.99,
#   'name': 'Organic Napa Cabbage',
#   'slug': 'produce-organic-napa-cabbage-b07ftvynm3',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41gb0EUnQ-L.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 5.99,
#   'name': 'Organic Angel Sweet Grape Tomato',
#   'slug': 'sunset-organic-angel-sweet-grape-tomato-b07g4l3dnb',
#   'brand': 'SUNSET',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51FLTsEUwGL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 4.99,
#   'name': 'Shanghai Baby Bok Choy Asian Salad, 16 OZ',
#   'slug': '4earth-farms-shanghai-baby-bok-choy-asian-salad-16-oz-b0bnpdcbx3',
#   'brand': '4Earth Farms',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/411iCgFg-BL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 3.39,
#   'name': '365 by Whole Foods Market, Organic Sweet Baby Lettuces, 5 Ounce',
#   'slug': '365-by-whole-foods-market-365-by-whole-foods-market-organic-sweet-baby-lettuces-5-ounce-b074h54n3s',
#   'brand': '365 by Whole Foods Market',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51uECfdnCkL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 3.39,
#   'name': '365 by Whole Foods Market, Organic Spring Spinach Mix, 5 Ounce',
#   'slug': '365-by-whole-foods-market-365-by-whole-foods-market-organic-spring-spinach-mix-5-ounce-b074h6x588',
#   'brand': '365 by Whole Foods Market',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51SnCD55g6L.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.79,
#   'name': 'Organic Red Radish Bunch',
#   'slug': 'produce-organic-red-radish-bunch-b000rh1nf2',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41GTxAHNmOL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 3.39,
#   'name': 'Organic Baby Spinach Salad, 5 OZ',
#   'slug': '365-by-whole-foods-market-organic-baby-spinach-salad-5-oz-b0bfg3bhnh',
#   'brand': '365 by Whole Foods Market',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41U4W57YSCL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.29,
#   'name': 'Green Onion',
#   'slug': 'produce-green-onion-b002b9280s',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/21GY-86s6HL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 3.99,
#   'name': 'Lemon Bag',
#   'slug': 'produce-lemon-bag-b00134m726',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41aiWrtqkvL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'name': 'Organic Mint',
#   'slug': 'produce-organic-mint-b07gyncjfz',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41wipLIB0GL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 4.99,
#   'name': 'Brussels Sprouts',
#   'slug': 'produce-brussels-sprouts-b003iq3peq',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31ClTHhsVjL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.29,
#   'name': 'Green Onion',
#   'slug': 'produce-green-onion-b002b9280s',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/21GY-86s6HL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.29,
#   'name': 'Romaine Lettuce',
#   'slug': 'produce-romaine-lettuce-b000nsfqik',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41QASmgWpuL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.99,
#   'name': 'Organic Slicing Cucumbers',
#   'slug': 'produce-organic-slicing-cucumbers-b000p6j1p4',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31bPNRjtLbS.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.99,
#   'name': 'Macintosh Apple',
#   'slug': 'produce-macintosh-apple-b07fz1slwb',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51zji-9agGL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 3.99,
#   'name': 'Organic Spinach, 9 OZ',
#   'slug': 'olivias-organics-organic-spinach-9-oz-b07d7bnb3t',
#   'brand': 'OLIVIAS ORGANICS',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41vLpUiq0bL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 3.99,
#   'name': 'Baby Butterhead Lettuce, 1 EA',
#   'slug': 'gotham-greens-baby-butterhead-lettuce-1-ea-b0793hq4qv',
#   'brand': 'GOTHAM GREENS',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41KkCiv8lNL.jpg',
#   'store': 10031,
#   'isLocal': True},
#  {'regularPrice': 3.99,
#   'name': 'Pee Wee Mixed Potato Bag, 16 OZ',
#   'slug': 'produce-pee-wee-mixed-potato-bag-16-oz-b07fts54ky',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41H-8TrUsqL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 4.99,
#   'name': 'Organic Chopped Kale Caesar Salad Kit, 9.25 OZ',
#   'slug': '365-by-whole-foods-market-organic-chopped-kale-caesar-salad-kit-925-oz-b07b66g7mt',
#   'brand': '365 by Whole Foods Market',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41sCzdSmbvL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.29,
#   'name': 'Macho Plantain Banana',
#   'slug': 'produce-macho-plantain-banana-b000se7y7u',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31f9xDmlcvL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 3.99,
#   'name': 'Shallot',
#   'slug': 'produce-shallot-b07q5bn5m9',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31HaWu3tORL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 2.99,
#   'name': 'Organic Romaine Salad, 10 OZ',
#   'slug': '365-by-whole-foods-market-organic-romaine-salad-10-oz-b074h58yct',
#   'brand': '365 by Whole Foods Market',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41B6vLjqU2L.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 6.99,
#   'name': 'Organic Raspberries, 12 OZ',
#   'slug': 'produce-organic-raspberries-12-oz-b08vld2xr7',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/319WK6rCtPL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 4.99,
#   'name': 'Jumbo Pomegranate',
#   'slug': 'produce-jumbo-pomegranate-b000p6g0yo',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41ciJ5lsNmL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'name': 'Organic Cripps Pink Apple',
#   'slug': 'produce-organic-cripps-pink-apple-b005kcihty',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41ufekQ9-1L.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 2.49,
#   'name': 'Organic Gala Apples',
#   'slug': 'produce-organic-gala-apples-b001gip5ci',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41-Lji5mrML.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 1.99,
#   'name': 'Organic Slicing Cucumbers',
#   'slug': 'produce-organic-slicing-cucumbers-b001pletdc',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31WocSTedFL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 3.99,
#   'name': 'Organic Broccoli',
#   'slug': 'produce-organic-broccoli-b000p6l3k0',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41XlpGAHrNL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 2.99,
#   'name': 'Organic Red Leaf Lettuce',
#   'slug': 'produce-organic-red-leaf-lettuce-b000p6h2j6',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/414qocoCOcL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.99,
#   'name': 'Organic Shallots, 3 OZ',
#   'slug': 'produce-organic-shallots-3-oz-b07d6vcmnj',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51gcrhfpLVL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 5.49,
#   'name': 'Caesar Salad Kit, 6.35 OZ',
#   'slug': 'gotham-greens-caesar-salad-kit-635-oz-b0d84dfbf1',
#   'brand': 'GOTHAM GREENS',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51rt-czQL8L.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.99,
#   'name': 'Jack Be Little Pumpkin',
#   'slug': 'produce-jack-be-little-pumpkin-b07fzbg6bl',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31spq5tMnaL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.69,
#   'name': 'Organic Russet Potato',
#   'slug': 'produce-organic-russet-potato-b000p6l454',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41sThLLZMLL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 2.99,
#   'name': 'Organic Shredded Romaine Lettuce, 9 OZ',
#   'slug': 'earthbound-farm-organic-shredded-romaine-lettuce-9-oz-b09vk6k7k6',
#   'brand': 'EARTHBOUND FARM',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41inledP4HL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 3.49,
#   'name': 'Brown Asian Pear',
#   'slug': 'produce-brown-asian-pear-b07hmbyrzl',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/412vfZPiKtL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 2.99,
#   'name': 'Organic Thyme',
#   'slug': 'produce-organic-thyme-b07pldchqz',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/4146hd4XDJL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'name': 'Organic Yellow Onion',
#   'slug': 'produce-organic-yellow-onion-b001gip2bm',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31oJQMLwNsL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 2.49,
#   'name': 'Cara Cara Navel Orange',
#   'slug': 'produce-cara-cara-navel-orange-b07nqzttf8',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31DZlJBBQaL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 3.79,
#   'name': 'Organic Baby Bella Mushrooms',
#   'slug': 'produce-organic-baby-bella-mushrooms-b07nqdlf47',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41sMtqZkAQL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.19,
#   'name': 'Organic Lemons',
#   'slug': 'produce-organic-lemons-b000p6g0u8',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31rWXA3xkGL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.69,
#   'name': 'Organic Carrot Bag, 16 OZ',
#   'slug': 'produce-organic-carrot-bag-16-oz-b00e3jelz4',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31JPoMNITXL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.29,
#   'name': 'Organic Mint Bunch',
#   'slug': 'produce-organic-mint-bunch-b07fy54jjv',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/410EgCZy3qL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'name': 'Organic Chives',
#   'slug': 'produce-organic-chives-b079jt3m9n',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41rqQsfl2nL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 5.99,
#   'name': 'Flavor Bomb Cherry Tomatoes, 12 OZ',
#   'slug': 'sunset-flavor-bomb-cherry-tomatoes-12-oz-b09tx9vs2q',
#   'brand': 'SUNSET',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51bhpK4MpIL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'name': 'Organic Loose Red Beet',
#   'slug': 'produce-organic-loose-red-beet-b07fyyb71x',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41V-ZAERbnL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 2.59,
#   'name': 'Organic Petite Baby Carrots, 12 OZ',
#   'slug': 'produce-organic-petite-baby-carrots-12-oz-b078j13fyq',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41R24MkksiL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 5.99,
#   'name': 'Organic Campari Tomatoes',
#   'slug': 'sunset-organic-campari-tomatoes-b007eizju2',
#   'brand': 'SUNSET',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51uwhYrwaZL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 6.49,
#   'name': 'PRODUCE Organic On the Vine Tomato, 12 OZ',
#   'slug': 'sunset-produce-organic-on-the-vine-tomato-12-oz-b0cw3d6kst',
#   'brand': 'SUNSET',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51IxVh7R-OL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.69,
#   'name': 'Organic Carrots',
#   'slug': 'produce-organic-carrots-b07fy873ss',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31YgUJQWWOL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'name': 'Baby Bella Mushrooms',
#   'slug': 'produce-baby-bella-mushrooms-b07fzhrm35',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/4189eTCf3pL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'name': 'Sliced Baby Bella Mushrooms',
#   'slug': 'produce-sliced-baby-bella-mushrooms-b00e3k22m2',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51YXX2Inq-L.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.29,
#   'name': 'Organic Carrot Bunch',
#   'slug': 'produce-organic-carrot-bunch-b000p6g0eo',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/412fBUAv0pL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.99,
#   'name': 'Organic Yellow Potato',
#   'slug': 'produce-organic-yellow-potato-b07py3gqsq',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31dGomLl2VL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 2.99,
#   'name': 'Organic Eggplant',
#   'slug': 'produce-organic-eggplant-b001plgqpq',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31iraWc8OQL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 2.99,
#   'name': 'Organic Dill',
#   'slug': 'produce-organic-dill-b07fy6sdg9',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41s0UtWXtcL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'name': 'Organic D Anjou Pear',
#   'slug': 'produce-organic-d-anjou-pear-b000p6l3qe',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41DVoM56cyL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 1.49,
#   'name': 'Delicata Squash',
#   'slug': 'produce-delicata-squash-b07ftxm6ff',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41RPJK4qkVL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 2.49,
#   'name': 'White Mushrooms 8oz, 8 Ounce',
#   'slug': 'produce-white-mushrooms-8oz-8-ounce-b07fz177bb',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41E1m-p-BZL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'name': 'Mini Cucumbers',
#   'slug': 'produce-mini-cucumbers-b07d79rfvk',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31bYatrcLKL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.39,
#   'name': 'Organic Peeled Baby Carrots',
#   'slug': 'produce-organic-peeled-baby-carrots-b000p6h3v8',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41nBGt6npoL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'name': 'Organic Green Leaf Lettuce',
#   'slug': 'produce-organic-green-leaf-lettuce-b000p6j14a',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/4148io0cF1L.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'name': 'Organic Peeled Butternut Squash',
#   'slug': 'produce-organic-peeled-butternut-squash-b07fzkxqqw',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41yBVDgC19L.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 2.69,
#   'name': 'Organic Red Grapefruit',
#   'slug': 'produce-organic-red-grapefruit-b000p6g148',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41XqQ0F4c9L.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 3.99,
#   'name': 'Organic Grape Tomatoes',
#   'slug': 'produce-organic-grape-tomatoes-b000nocro0',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41B94RZf-9L.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 3.99,
#   'name': 'Organic Tomato On The Vine',
#   'slug': 'produce-organic-tomato-on-the-vine-b000pkmaoy',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51blFCqR6rL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 5.99,
#   'name': 'Organic Green Kiwi',
#   'slug': 'produce-organic-green-kiwi-b001l1hfku',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41HBaHY-MmL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 3.29,
#   'name': 'Orange Bell Pepper',
#   'slug': 'produce-orange-bell-pepper-b000p6j1a4',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31wnGQ-lKJL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 3.29,
#   'name': 'Yellow Bell Pepper',
#   'slug': 'produce-yellow-bell-pepper-b001l1j0ye',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31h1YdnOKgL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 1.99,
#   'name': 'Organic Vidalia Onion',
#   'slug': 'produce-organic-vidalia-onion-b07hmbyt6j',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41DgW5OoMuL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 3.29,
#   'name': 'Red Bell Peppers',
#   'slug': 'produce-red-bell-peppers-b08ds45y8w',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31oCCnCiAPL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 0.59,
#   'name': 'Lime',
#   'slug': 'produce-lime-b000nsfqiu',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51PWSuYawVL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.99,
#   'name': 'Cortland Apple',
#   'slug': 'produce-cortland-apple-b07fzgvvvd',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41ioJQMObSL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 4.49,
#   'name': 'Organic Baby Bok Choy, 3 CT',
#   'slug': 'cal-organic-organic-baby-bok-choy-3-ct-b09hqfm8lg',
#   'brand': 'Cal Organic',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41BsU-aZJ1L.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 0.79,
#   'name': 'Organic Banana',
#   'slug': 'produce-organic-banana-b0014gpskq',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/21Vsh5Se30L.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 6.99,
#   'name': 'Sweetest Batch Blueberries, 11 OZ',
#   'slug': 'produce-sweetest-batch-blueberries-11-oz-b07yfdqxq9',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31smRoV7IxL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'name': 'Organic Large Hass Avocados',
#   'slug': 'produce-organic-large-hass-avocados-b0014glse6',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31-Um-N0-OL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.79,
#   'name': 'Organic Green Onions, 5.5 OZ',
#   'slug': 'cal-organic-organic-green-onions-55-oz-b09hqgs1k8',
#   'brand': 'Cal Organic',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41vsi9D3KML.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.59,
#   'name': 'Cilantro Bunch',
#   'slug': 'produce-cilantro-bunch-b003imcnh0',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41PPcCmhqaL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 5.99,
#   'name': 'Organic Baby Spinach, 10 OZ',
#   'slug': 'organic-girl-organic-baby-spinach-10-oz-b00k0eeih2',
#   'brand': 'Organic Girl',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51-VQeEPpjL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 4.49,
#   'name': 'Organic Baby Spinach, 5 OZ',
#   'slug': 'organic-girl-organic-baby-spinach-5-oz-b004sv5jwq',
#   'brand': 'Organic Girl',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/512RGZYistL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.99,
#   'name': 'Organic Daikon Radish',
#   'slug': 'produce-organic-daikon-radish-b07nr221z8',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31D45h83DKL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 2.99,
#   'name': 'Organic Leeks',
#   'slug': 'produce-organic-leeks-b0011cxrom',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31--01waMwL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 6.99,
#   'name': 'Angel Sweet Cherry Tomatoes, 24 OZ',
#   'slug': 'sunset-angel-sweet-cherry-tomatoes-24-oz-b079vmh8w6',
#   'brand': 'SUNSET',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51c0kBkd7IL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.79,
#   'name': 'Organic Carrot Chips, 16 OZ',
#   'slug': 'produce-organic-carrot-chips-16-oz-b009sc4noa',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41oMmTdNKjL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 5.99,
#   'name': 'Organic Upstate Abundance Yellow Creamer Potatoes, 24 OZ',
#   'slug': 'row-7-organic-upstate-abundance-yellow-creamer-potatoes-24-oz-b0cgdybyhm',
#   'brand': 'Row 7',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41CEEBIMazL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.69,
#   'name': 'Broccoli Crowns',
#   'slug': 'produce-broccoli-crowns-b000p6l3j6',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51D706K4sxL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 5.99,
#   'name': 'Organic Lemon Bag',
#   'slug': 'produce-organic-lemon-bag-b0792p6wbp',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/413KZuhTtDL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 6.99,
#   'name': 'Produce Wild Wonder Cherry Tomatoes, 24 OZ',
#   'slug': 'sunset-produce-wild-wonder-cherry-tomatoes-24-oz-b01a6b5mgy',
#   'brand': 'SUNSET',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51-7aAqOqeL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.99,
#   'name': 'Organic Spaghetti Squash',
#   'slug': 'produce-organic-spaghetti-squash-b000rgwkg4',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31P5ppvHrhL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 3.99,
#   'name': 'Basil, 1.25 OZ',
#   'slug': 'gotham-greens-basil-125-oz-b01m4jd5jh',
#   'brand': 'GOTHAM GREENS',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41lusK4G0FL.jpg',
#   'store': 10031,
#   'isLocal': True},
#  {'regularPrice': 5.79,
#   'name': '365 Everyday Value, Organic Salad Kit - Asian Inspired, 12 oz',
#   'slug': '365-by-whole-foods-market-365-everyday-value-organic-salad-kit-asian-inspired-12-oz-b07b67y9mh',
#   'brand': '365 by Whole Foods Market',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41wPwBhKuwL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.99,
#   'name': 'Organic Butternut Squash',
#   'slug': 'produce-organic-butternut-squash-b002qy3u5a',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41LNdkUcyML.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 1.99,
#   'name': 'Sprout Bean Mung',
#   'slug': 'produce-sprout-bean-mung-b07d7bd5tq',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51fhcEo0JwL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'name': 'Organic Ambrosia Apple',
#   'slug': 'produce-organic-ambrosia-apple-b01leyfwq2',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41tQcSJnq4L.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 3.49,
#   'name': 'Organic Peeled Baby Carrots',
#   'slug': 'produce-organic-peeled-baby-carrots-b000rgwjx8',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41dtY67R8xL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 3.69,
#   'name': 'Organic Sliced White Mushrooms',
#   'slug': 'produce-organic-sliced-white-mushrooms-b07fzg3rdy',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/5111bAwvzOL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 4.99,
#   'name': 'Organic Cauliflower',
#   'slug': 'produce-organic-cauliflower-b000p6g0gm',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51DnhsR8x8L.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 3.79,
#   'name': 'Sweet Potato Bag',
#   'slug': 'produce-sweet-potato-bag-b078w9zj1g',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51jxH3y-Z3L.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 5.99,
#   'name': 'Organic Green Kiwi, 16 OZ',
#   'slug': 'produce-organic-green-kiwi-16-oz-b07lft2c9h',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41vWJbYsS-L.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 3.49,
#   'name': 'Organic Celery Hearts',
#   'slug': 'produce-organic-celery-hearts-b00e3j92ps',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41lLWrJVpJL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'name': 'Organic Lady Alice Apple',
#   'slug': 'produce-organic-lady-alice-apple-b0050prhsi',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41xdoUJlcRL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 4.99,
#   'name': 'Heirloom Tomato',
#   'slug': 'produce-heirloom-tomato-b003tq34au',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51fuxUsEExL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 4.79,
#   'name': 'Rainbow Mix Microgreens, 2 OZ',
#   'slug': 'aerofarms-rainbow-mix-microgreens-2-oz-b0b1468ymv',
#   'brand': 'AeroFarms',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51C0k67CYhL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 0.79,
#   'name': 'Lemon',
#   'slug': 'produce-lemon-b001l1krnc',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31rWXA3xkGL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 4.99,
#   'name': 'Organic Green Jalapeno Pepper',
#   'slug': 'produce-organic-green-jalapeno-pepper-b07fzhq5l8',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31mqwAvNHTL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 2.99,
#   'name': 'Organic Iceberg Lettuce',
#   'slug': 'produce-organic-iceberg-lettuce-b0011cxrvk',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41pLU0UecmL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.49,
#   'name': 'Organic Dill Bunch',
#   'slug': 'produce-organic-dill-bunch-b07fz2nyz3',
#   'brand': 'PRODUCE',
# ...
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 5.99,
#   'salePrice': 5.32,
#   'incrementalSalePrice': 4.79,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-11T23:59:59Z',
#   'name': 'Organic Green Asparagus',
#   'slug': 'produce-organic-green-asparagus-b002qy5pb2',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41zY14ps7pL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 2.49,
#   'name': 'Sliced White Mushrooms',
#   'slug': 'produce-sliced-white-mushrooms-b07fxt18r8',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41QHPbGf-YL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 15.99,
#   'salePrice': 13.33,
#   'incrementalSalePrice': 12,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-11T23:59:59Z',
#   'name': 'Organic Medjool Dates, 32 OZ',
#   'slug': 'produce-organic-medjool-dates-32-oz-b079kzwqwj',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51kzzI9MT5L.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 1.49,
#   'salePrice': 5.56,
#   'incrementalSalePrice': 5,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-11T23:59:59Z',
#   'primeMultiple': 4,
#   'saleMultiple': 4,
#   'name': 'Medium Hass Avocado',
#   'slug': 'produce-medium-hass-avocado-b000nogkn4',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51ukRMsmDIL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 3.39,
#   'salePrice': 3.32,
#   'incrementalSalePrice': 2.99,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-11T23:59:59Z',
#   'name': 'Organic Arugula Baby Spinach Salad, 5 OZ',
#   'slug': '365-by-whole-foods-market-organic-arugula-baby-spinach-salad-5-oz-b074vd6r4r',
#   'brand': '365 by Whole Foods Market',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41TQibNoSaL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 6.49,
#   'salePrice': 5.54,
#   'incrementalSalePrice': 4.99,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-11T23:59:59Z',
#   'name': 'Mini Sweet Peppers, 24 OZ',
#   'slug': 'produce-mini-sweet-peppers-24-oz-b09srwg2lj',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41ulsm9F5uL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'name': 'Organic Oregano',
#   'slug': 'produce-organic-oregano-b079jy4syg',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41QrtRcfmPL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 4.99,
#   'name': 'Black Seedless Grapes, 16 OZ',
#   'slug': 'produce-black-seedless-grapes-16-oz-b07ftsdwwl',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41cgxqgcOlL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 4.99,
#   'salePrice': 4.43,
#   'incrementalSalePrice': 3.99,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-11T23:59:59Z',
#   'name': 'Organic Pomegranate',
#   'slug': 'produce-organic-pomegranate-b07fz82x4t',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41PGOsWRRBL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 5.99,
#   'name': 'Crunchy Sesame Ramen Salad Kit, 10 OZ',
#   'slug': 'ark-foods-crunchy-sesame-ramen-salad-kit-10-oz-b0bpwm28fg',
#   'brand': 'Ark Foods',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41xAJg1mIdL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 5.49,
#   'salePrice': 4.43,
#   'incrementalSalePrice': 3.99,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-11T23:59:59Z',
#   'name': 'Organic Mixed Fingerling Potato Bag',
#   'slug': 'produce-organic-mixed-fingerling-potato-bag-b078b5c1f6',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51dpbtBny-L.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'salePrice': 2.21,
#   'incrementalSalePrice': 1.99,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-11T23:59:59Z',
#   'name': 'Organic Red Sweet Potato',
#   'slug': 'produce-organic-red-sweet-potato-b00qt73u14',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31mAABX3NBL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 15.99,
#   'salePrice': 13.33,
#   'incrementalSalePrice': 12,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-11T23:59:59Z',
#   'name': 'Organic Pitted Medjool Dates, 24 OZ',
#   'slug': 'natural-delights-organic-pitted-medjool-dates-24-oz-b0clb4h2bv',
#   'brand': 'NATURAL DELIGHTS',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51zOZoJS0uL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 3.29,
#   'salePrice': 3.1,
#   'incrementalSalePrice': 2.79,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-11T23:59:59Z',
#   'name': 'Honeycrisp Apples',
#   'slug': 'produce-honeycrisp-apples-b000rgzmtq',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/413SS6wy-cL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 6.99,
#   'name': 'Organic Gold Kiwi',
#   'slug': 'zespri-organic-gold-kiwi-b079jmtdh4',
#   'brand': 'ZESPRI',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/211DETWET8L.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 4.49,
#   'salePrice': 4.43,
#   'incrementalSalePrice': 3.99,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-11T23:59:59Z',
#   'name': 'Organic Mini Cucumbers, 1 EA',
#   'slug': 'produce-organic-mini-cucumbers-1-ea-b07ftywccd',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/21u-zL4o4FL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 6.99,
#   'salePrice': 5.54,
#   'incrementalSalePrice': 4.99,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-11T23:59:59Z',
#   'name': 'Brussels Sprouts',
#   'slug': 'produce-brussels-sprouts-b08285kyvt',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/71LnmKVECdL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 5.49,
#   'salePrice': 4.43,
#   'incrementalSalePrice': 3.99,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-11T23:59:59Z',
#   'name': 'Organic Red Creamer Potato Bag, 24 OZ',
#   'slug': 'produce-organic-red-creamer-potato-bag-24-oz-b07fytzq2x',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51lIaltzWtL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 8.99,
#   'salePrice': 7.49,
#   'incrementalSalePrice': 6.74,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-11T23:59:59Z',
#   'name': 'Organic Medjool Dates, 16 OZ',
#   'slug': 'produce-organic-medjool-dates-16-oz-b00c0tilqy',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51gsjO0IeHL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 4.49,
#   'salePrice': 3.88,
#   'incrementalSalePrice': 3.49,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-04T23:59:59Z',
#   'name': 'Produce Wild Wonder Cherry Tomatoes, 12 OZ',
#   'slug': 'sunset-produce-wild-wonder-cherry-tomatoes-12-oz-b00e3jlswi',
#   'brand': 'SUNSET',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41s4mQAAydL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 4.99,
#   'name': 'Green Asparagus',
#   'slug': 'produce-green-asparagus-b078zg3ths',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/418O-UbxYlL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 7.49,
#   'name': 'Red Seedless Grapes, 48 OZ',
#   'slug': 'produce-red-seedless-grapes-48-oz-b097npl6cc',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/510E9YB-x8L.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 5.99,
#   'name': 'Jumbo Blueberries, 9.8 OZ',
#   'slug': 'produce-jumbo-blueberries-98-oz-b08821bx1c',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41xWurO-JRL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'salePrice': 2.21,
#   'incrementalSalePrice': 1.99,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-11T23:59:59Z',
#   'name': 'Comice Pear',
#   'slug': 'produce-comice-pear-b000p6j0wi',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/418v6at9FWL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 4.99,
#   'name': '365 by WFM Organic Sliced Portobello Mushrooms, 6 OZ',
#   'slug': '365-by-whole-foods-market-365-by-wfm-organic-sliced-portobello-mushrooms-6-oz-b077zxhxj6',
#   'brand': '365 by Whole Foods Market',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41dychidyPL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 4.49,
#   'salePrice': 3.88,
#   'incrementalSalePrice': 3.49,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-04T23:59:59Z',
#   'name': 'Produce Angel Sweet Cherry Tomatoes, 1 PT',
#   'slug': 'sunset-produce-angel-sweet-cherry-tomatoes-1-pt-b07g4qwrnf',
#   'brand': 'SUNSET',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/517qgykthbL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 3.79,
#   'salePrice': 3.32,
#   'incrementalSalePrice': 2.99,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-04T23:59:59Z',
#   'name': 'Baby Green Leaf Lettuce, 4 OZ',
#   'slug': 'little-leaf-farms-baby-green-leaf-lettuce-4-oz-b07fz18dxf',
#   'brand': 'LITTLE LEAF FARMS',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51UQGo5-GTL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.99,
#   'salePrice': 2.77,
#   'incrementalSalePrice': 2.49,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-11T23:59:59Z',
#   'name': 'Organic Fuji Apples',
#   'slug': 'produce-organic-fuji-apples-b000ytxxdi',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/317T0-EqzGL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 5.99,
#   'salePrice': 5.54,
#   'incrementalSalePrice': 4.99,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-11T23:59:59Z',
#   'name': 'Seedless Red Holiday Grapes',
#   'slug': 'produce-seedless-red-holiday-grapes-b08j87sxfy',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31CWhc0KOGL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 3.79,
#   'salePrice': 3.32,
#   'incrementalSalePrice': 2.99,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-04T23:59:59Z',
#   'name': 'Baby Red & Green Leaf Lettuce, 4 OZ',
#   'slug': 'little-leaf-farms-baby-red-green-leaf-lettuce-4-oz-b07fz1tzw9',
#   'brand': 'LITTLE LEAF FARMS',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51wV-HpSmaL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 4.99,
#   'name': 'Long Hot Green Pepper',
#   'slug': 'produce-long-hot-green-pepper-b07fzbg2tm',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31sYqqIVTbL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 9.49,
#   'salePrice': 7.91,
#   'incrementalSalePrice': 7.12,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-11T23:59:59Z',
#   'name': 'Organic Pitted Medjool Dates, 12 OZ',
#   'slug': 'produce-organic-pitted-medjool-dates-12-oz-b075m1sxl2',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51X0X7e1cHL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 3.99,
#   'name': 'Greenhouse Crunch, 4.5 OZ',
#   'slug': 'gotham-greens-greenhouse-crunch-45-oz-b00ltxe062',
#   'brand': 'GOTHAM GREENS',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41ePWjrYkVL.jpg',
#   'store': 10031,
#   'isLocal': True},
#  {'regularPrice': 3.49,
#   'name': 'Organic Red Radishes, 12 OZ',
#   'slug': 'cal-organic-organic-red-radishes-12-oz-b079vlpq2l',
#   'brand': 'Cal Organic',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/51GhcmeAZSL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 4.99,
#   'salePrice': 3.88,
#   'incrementalSalePrice': 3.49,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-11T23:59:59Z',
#   'name': 'Organic Red Seedless Grapes',
#   'slug': 'produce-organic-red-seedless-grapes-b000rgyji6',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41GUbT2MkgL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 3.49,
#   'salePrice': 6.66,
#   'incrementalSalePrice': 5.99,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-11T23:59:59Z',
#   'primeMultiple': 2,
#   'saleMultiple': 2,
#   'name': 'Raspberries',
#   'slug': 'produce-raspberries-b000p6g12u',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/418A8vmsKfL.jpg',
#   'store': 10031,
#   'isLocal': True},
#  {'regularPrice': 1.99,
#   'name': 'Yellow Squash',
#   'slug': 'produce-yellow-squash-b000p6h2pa',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/31hETLsKOuL.jpg',
#   'store': 10031,
#   'isLocal': False,
#   'uom': 'lb'},
#  {'regularPrice': 3.39,
#   'salePrice': 3.32,
#   'incrementalSalePrice': 2.99,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-11T23:59:59Z',
#   'name': 'Organic Baby Arugula Salad, 5 OZ',
#   'slug': '365-by-whole-foods-market-organic-baby-arugula-salad-5-oz-b09zhx8y9v',
#   'brand': '365 by Whole Foods Market',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41jp9fdoTRL.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 2.49,
#   'name': 'Organic Frisee Green',
#   'slug': 'produce-organic-frisee-green-b07fzgkzl4',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41P481xCLML.jpg',
#   'store': 10031,
#   'isLocal': False},
#  {'regularPrice': 5.99,
#   'salePrice': 5.54,
#   'incrementalSalePrice': 4.99,
#   'saleStartDate': '2025-10-29T00:00:00Z',
#   'saleEndDate': '2025-11-11T23:59:59Z',
#   'name': 'Organic Blueberries',
#   'slug': 'produce-organic-blueberries-b077n7tr5g',
#   'brand': 'PRODUCE',
#   'imageThumbnail': 'https://m.media-amazon.com/images/S/assets.wholefoodsmarket.com/PIE/product/41ztFVI9nmL.jpg',
#   'store': 10031,
#   'isLocal': False}]

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

URL = "https://www.wholefoodsmarket.com/products/produce"

headers = {
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 "
                  "(KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

resp = requests.get(URL, headers=headers, timeout=30)
resp.raise_for_status()
soup = BeautifulSoup(resp.text, "html.parser")

# Product links on this page point to /product/...; grab their text
items = []
for a in soup.select('a[href^="/product/"]'):
    name = a.get_text(strip=True)
    href = urljoin(URL, a["href"])
    if name:  # skip empty anchors
        items.append({"name": name, "url": href})

print(f"Found {len(items)} items")
for it in items[:15]:
    print(it["name"], "->", it["url"])
# Out:
# Found 60 items
# PRODUCEOrganic English Cucumbers -> https://www.wholefoodsmarket.com/product/produce-organic-english-cucumbers-b07dlgkrtd
# 365 by Whole Foods MarketPackaged Vegetables, Green Beans - Trimmed -> https://www.wholefoodsmarket.com/product/365-by-whole-foods-market-packaged-vegetables-green-beans-trimmed-b078j118fh
# PRODUCEOrganic Slicing Cucumbers -> https://www.wholefoodsmarket.com/product/produce-organic-slicing-cucumbers-b0040qylw8
# PRODUCEMandarin 3 Pound Bag -> https://www.wholefoodsmarket.com/product/produce-mandarin-3-pound-bag-1ob60198
# Prima Frutta Packing Co.California Rainier Cherries -> https://www.wholefoodsmarket.com/product/prima-frutta-packing-co-california-rainier-cherries-2btlh8bh
# PRODUCEGold Nugget Mandarins -> https://www.wholefoodsmarket.com/product/produce-gold-nugget-mandarins-1ob60jb3
# Whole Foods MarketOrganic Baby Spinach Salad -> https://www.wholefoodsmarket.com/product/whole-foods-market-organic-baby-spinach-salad-b088k6v6bn
# PRODUCEBrussels Organic Sprouts, 16 Ounce -> https://www.wholefoodsmarket.com/product/produce-brussels-organic-sprouts-16-ounce-b004daqpr0
# PRODUCEOrganic White Onion -> https://www.wholefoodsmarket.com/product/produce-organic-white-onion-b000rgznfy
# PRODUCEOrganic Red Cabbage -> https://www.wholefoodsmarket.com/product/produce-organic-red-cabbage-b000rh1mxk
# PRODUCEOrganic Mint -> https://www.wholefoodsmarket.com/product/produce-organic-mint-b07gyncjfz
# Organic GirlOrganic Baby Spring Salad Mix, 10 OZ -> https://www.wholefoodsmarket.com/product/organic-girl-organic-baby-spring-salad-mix-10-oz-b00k0eeio0
# PRODUCEZucchini Squash -> https://www.wholefoodsmarket.com/product/produce-zucchini-squash-b000p6g1ac
# PRODUCEOrganic Yellow Onion Bag -> https://www.wholefoodsmarket.com/product/produce-organic-yellow-onion-bag-b07ftjcyl3
# PRODUCEOrganic Green Cabbage -> https://www.wholefoodsmarket.com/product/produce-organic-green-cabbage-b000p6h29q
